# %%
from tutor import tutor

choix_de_Bob = input("Par où Bob veut-il passer aujoud'hui ? ")

if choix_de_Bob == "lac" :
    print("Bob doit emprunter le chemin bleu")
elif choix_de_Bob == "ville" :
    print("Bob doit emprunter le chemin brun")
elif choix_de_Bob == "parc" :
    print("Bob doit emprunter le chemin vert")
else :
    print("Bob doit emprunter le chemin rouge")
    
print("A demain pour un autre choix!")

tutor()
